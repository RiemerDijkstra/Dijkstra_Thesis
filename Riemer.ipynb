# %%
from tqdm import tqdm
import re

from gensim.corpora.wikicorpus import extract_pages, filter_wiki, process_article
# Out:
# /home/riemer/.local/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def text_from_raw(raw):
    txt = filter_wiki(raw).strip()
    txt = re.sub("\n+", "\n", txt)
    return re.sub("'+", "'", txt)

def dump_to_list(filename, max_articles=1e10):
    with open(filename) as handle:
        pg_iter = extract_pages(handle)
        for (title, raw_text, page_id), _ in tqdm(zip(pg_iter, range(max_articles))):
            yield title, text_from_raw(raw_text), int(page_id)

# %%
pgs = list(dump_to_list("enwiki-latest-pages-articles16.xml-p20460153p20570392.bz2", max_articles=1000))
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-04608f2a5bdd> in <module>
# ----> 1 pgs = list(dump_to_list("enwiki-latest-pages-articles16.xml-p20460153p20570392.bz2", max_articles=1000))
#
# <ipython-input-2-f0caea0fc172> in dump_to_list(filename, max_articles)
#       7     with open(filename) as handle:
#       8         pg_iter = extract_pages(handle)
# ----> 9         for (title, raw_text, page_id), _ in tqdm(zip(pg_iter, range(max_articles))):
#      10             yield title, text_from_raw(raw_text), int(page_id)
#
# ~/.local/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# ...

# %%
pgs[1]
# Out:
# ('Anarchism',
# ...
